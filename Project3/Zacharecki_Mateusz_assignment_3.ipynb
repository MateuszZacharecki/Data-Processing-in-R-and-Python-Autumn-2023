# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# %%
from Zacharecki_Mateusz_assignment_3 import *

# %%
BadgesDE = pd.read_xml("BadgesDE.xml")
BadgesRU = pd.read_xml("BadgesRU.xml")
BadgesUA = pd.read_xml("BadgesUA.xml")
CommentsDE = pd.read_xml("CommentsDE.xml")
CommentsRU = pd.read_xml("CommentsRU.xml")
CommentsUA = pd.read_xml("CommentsUA.xml")
PostHistoryDE = pd.read_xml("PostHistoryDE.xml")
PostHistoryRU = pd.read_xml("PostHistoryRU.xml")
PostHistoryUA = pd.read_xml("PostHistoryUA.xml")
PostLinksDE = pd.read_xml("PostLinksDE.xml")
PostLinksRU = pd.read_xml("PostLinksRU.xml")
PostLinksUA = pd.read_xml("PostLinksUA.xml")
PostsDE = pd.read_xml("PostsDE.xml")
PostsRU = pd.read_xml("PostsRU.xml")
PostsUA = pd.read_xml("PostsUA.xml")
TagsDE = pd.read_xml("TagsDE.xml")
TagsRU = pd.read_xml("TagsRU.xml")
TagsUA = pd.read_xml("TagsUA.xml")
UsersDE = pd.read_xml("UsersDE.xml")
UsersRU = pd.read_xml("UsersRU.xml")
UsersUA = pd.read_xml("UsersUA.xml")
VotesDE = pd.read_xml("VotesDE.xml")
VotesRU = pd.read_xml("VotesRU.xml")
VotesUA = pd.read_xml("VotesUA.xml")

# %%
Plot1(CommentsDE, CommentsRU, CommentsUA)

# %%
Plot2(PostsDE, PostsRU, PostsUA)

# %%
Plot3(UsersDE, UsersRU, UsersUA)

# %%
Plot4(CommentsDE, CommentsRU, CommentsUA)

# %%
Plot5(PostsDE, PostsRU, PostsUA)

# %%
Plot6(UsersDE, UsersRU, UsersUA)

# %%
Plot7(UsersDE)

# %%
Plot8(UsersDE)

# %%
Plot9(UsersRU)

# %%
Plot10(UsersRU)

# %%
Plot11(UsersUA)

# %%
Plot12(UsersDE, UsersRU, UsersUA)

# %%
Table1(PostsDE, UsersDE)
# Out:
#                                   Location  Count
# 0                                  Germany   5176
# 1                      St. Pölten, Austria   2235
# 2                          Berlin, Germany   1385
# 3                          Munich, Germany    840
# 4                           Fürth, Germany    771
# 5                                   Bayern    735
# 6  Hannover (Germany) and Sofia (Bulgaria)    693
# 7                                berlin.de    675
# 8                         Cologne, Germany    634
# 9                                   Europe    588

# %%
Plot13(Table1(PostsDE, UsersDE))

# %%
Table2(PostsRU, UsersRU)
# Out:
#                  Location  Count
# 0          Moscow, Russia   1406
# 1                  Russia    427
# 2                 Ukraine    406
# 3  St. Petersburg, Russia    339
# 4  London, United Kingdom    311
# 5          Palm Beach, FL    196
# 6           Kiev, Ukraine    193
# 7                  Europe    156
# 8                   Japan    141
# 9                      UK    108

# %%
Plot14(Table2(PostsRU, UsersRU))

# %%
Table3(PostsUA, UsersUA)
# Out:
#                              Location  Count
# 0                       Kyiv, Ukraine    686
# 1                       Киев, Украина    323
# 2   Львів, Львівська область, Україна    242
# 3                             Ukraine    211
# 4                       Kiev, Ukraine    107
# 5                     Dnipro, Ukraine     60
# 6                    Lüneburger Heide     40
# 7                    Kharkiv, Ukraine     39
# 8       Kyiv City, Kyiv city, Ukraine     36
# 9  Теплодар, Одеська область, Україна     34

# %%
Plot15(Table3(PostsUA, UsersUA))
